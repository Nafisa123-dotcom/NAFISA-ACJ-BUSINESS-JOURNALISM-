# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openpyxl

# %%
df = pd.read_excel('Macro_econ_aggregates.xlsx')

# %%
df.tail()
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 27         NaN  Notes : 1. Data for 2024-25 are First Revised ...        NaN
# 28         NaN     2. Data for 2025-26 are Provisional Estimates.        NaN
# 29         NaN  3. Population figures relate to mid-financial ...        NaN
# 30         NaN                          Also see Notes on Tables.        NaN
# 31         NaN         Source : National Statistics Office (NSO).        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 27        NaN        NaN        NaN        NaN        NaN        NaN
# 28        NaN        NaN        NaN        NaN        NaN        NaN
# 29        NaN        NaN        NaN        NaN        NaN        NaN
# 30        NaN        NaN        NaN        NaN        NaN        NaN
# 31        NaN        NaN        NaN        NaN        NaN        NaN

# %%
df.head()
# Out:
#    Unnamed: 0                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         NaN  TABLE 1 : MACRO-ECONOMIC AGGREGATES        NaN        NaN
# 1         NaN                  (At Current Prices)        NaN        NaN
# 2         NaN                  (Amount in ₹ Crore)        NaN        NaN
# 3         NaN                            Item/Year    2020-21    2021-22
# 4         NaN                                    1          2          3
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3    2022-23    2022-23    2023-24    2024-25    2025-26
# 4          4          5          6          7          8

# %%
df.shape
# Out:
# (32, 9)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                TABLE 1 : MACRO-ECONOMIC AGGREGATES
# 1          NaN                                (At Current Prices)
# 2          NaN                                (Amount in ₹ Crore)
# 3          NaN                                          Item/Year
# 4          NaN                                                  1
# 5          NaN                                                NaN
# 6          NaN                              Population (in Lakhs)
# 7          NaN                                GVA at Basic Prices
# 8          NaN                              Net Taxes on Products
# 9          NaN                             Gross Domestic Product
# 10         NaN                       Consumption of Fixed Capital
# 11         NaN                               Net Domestic Product
# 12         NaN           Primary Income Receivable from ROW (net)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    32
# Unnamed: 1     1
# Unnamed: 2     8
# Unnamed: 3     9
# Unnamed: 4     9
# Unnamed: 5     8
# Unnamed: 6     9
# Unnamed: 7     9
# Unnamed: 8     9
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1     object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6     object
# Unnamed: 7     object
# Unnamed: 8     object
# dtype: object

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.iloc[7:28]
# Out:
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 7                                 GVA at Basic Prices   18210997   21635584
# 8                               Net Taxes on Products    1643099    1961815
# 9                              Gross Domestic Product   19854096   23597399
# 10                       Consumption of Fixed Capital    2340587    2666804
# 11                               Net Domestic Product   17513509   20930595
# 12           Primary Income Receivable from ROW (net)    -266687    -277808
# 13                              Gross National Income   19587409   23319590
# 14                                Net National Income   17246821   20652786
# 15             Other Current Transfers (net) from ROW     552188     605444
# 16                   Gross National Disposable Income   20139597   23925034
# 17                     Net National Disposable Income   17799010   21258230
# ...
